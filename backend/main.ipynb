# %% [markdown]
# # Railway Wagon Inspection - Model Training
# This notebook contains the training pipeline for the Deblurring Model.

# %%
import sys
import os

# Fix for ModuleNotFoundError: No module named 'ml'
# Add current directory to path
if os.getcwd() not in sys.path:
    sys.path.append(os.getcwd())

# Also add 'backend' directory if running from the project root
if os.path.exists(os.path.join(os.getcwd(), 'backend')):
    sys.path.append(os.path.join(os.getcwd(), 'backend'))

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, random_split, Subset
from ml.dataset import DeblurDataset
from ml.model import DeblurUNet
from torchvision.utils import save_image
from tqdm import tqdm
import numpy as np
from backend import train

# %%
# Configuration
config = train.prepare_config()
config

# %%
# The training implementation now lives in backend.train.
# This notebook now relies on that shared logic instead of duplicating it locally.

# %%
# Run the training pipeline that now lives in backend.train
train.main(config)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-451060111.py in <cell line: 0>()
#       1 # Run the training pipeline that now lives in backend.train
# ----> 2 train.main(config)
#
# NameError: name 'train' is not defined
